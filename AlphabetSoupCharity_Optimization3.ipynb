# %% [markdown]
# <a href="https://colab.research.google.com/github/Ndleisenring/deep_learning_challenge/blob/main/AlphabetSoupCharity_Optimization3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns = ['EIN', 'NAME', 'STATUS'])
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association              0                      N      5000
# 1      Co-operative         1-9999                      N    108590
# 2       Association              0                      N      5000
# 3             Trust    10000-24999                      N      6692
# 4             Trust  100000-499999                      N    142590
# ...             ...            ...                    ...       ...
# 34294   Association              0                      N      5000
# 34295   Association              0                      N      5000
# 34296   Association              0                      N      5000
# 34297   Association              0                      N      5000
# 34298  Co-operative          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 9 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_counts = application_df['APPLICATION_TYPE'].value_counts()
app_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = app_counts[app_counts < 500].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
class_counts = application_df['CLASSIFICATION'].value_counts()
class_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Look at CLASSIFICATION value counts >1
class_counts[class_counts > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = class_counts[class_counts < 1000].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Look at ASK_AMT value counts for binning
ask_counts = application_df['ASK_AMT'].value_counts()
ask_counts
# Out:
# 5000        25398
# 10478           3
# 15583           3
# 63981           3
# 6725            3
#             ...
# 5371754         1
# 30060           1
# 43091152        1
# 18683           1
# 36500179        1
# Name: ASK_AMT, Length: 8747, dtype: int64

# %%
# Choose a cutoff value and create a list of ask amounts to be replaced
# use the variable name `ask_to_replace`
ask_to_replace = ask_counts[ask_counts < 25000].index

# Replace in dataframe
for cls in ask_to_replace:
    application_df['ASK_AMT'] = application_df['ASK_AMT'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['ASK_AMT'].value_counts()
# Out:
# 5000     25398
# Other     8901
# Name: ASK_AMT, dtype: int64

# %%
dummies_df = pd.get_dummies(application_df)
dummies_df
# Out:
#        IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0                  1                       0                     1
# 1                  1                       0                     0
# 2                  0                       0                     0
# 3                  1                       0                     0
# 4                  1                       0                     0
# ...              ...                     ...                   ...
# 34294              0                       0                     0
# 34295              0                       0                     0
# 34296              0                       0                     0
# 34297              1                       0                     0
# 34298              0                       0                     0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                         0                    0                    0
# 1                         0                    1                    0
# 2                         0                    0                    0
# 3                         0                    1                    0
# 4                         0                    1                    0
# ...                     ...                  ...                  ...
# 34294                     0                    0                    1
# 34295                     0                    0                    1
# 34296                     0                    1                    0
# 34297                     0                    0                    0
# 34298                     0                    1                    0
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        1                    0                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 34294                    0                    0                    0
# 34295                    0                    0                    0
# 34296                    0                    0                    0
# 34297                    1                    0                    0
# 34298                    0                    0                    0
#
#        APPLICATION_TYPE_T8  ...  INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  \
# 0                        0  ...                         0                   0
# 1                        0  ...                         0                   0
# 2                        0  ...                         0                   0
# 3                        0  ...                         0                   0
# 4                        0  ...                         1                   0
# ...                    ...  ...                       ...                 ...
# 34294                    0  ...                         0                   0
# 34295                    0  ...                         0                   0
# 34296                    0  ...                         0                   0
# 34297                    0  ...                         0                   0
# 34298                    0  ...                         0                   0
#
#        INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  INCOME_AMT_50M+  \
# 0                     0                       0                0
# 1                     0                       0                0
# 2                     0                       0                0
# 3                     0                       0                0
# 4                     0                       0                0
# ...                 ...                     ...              ...
# 34294                 0                       0                0
# 34295                 0                       0                0
# 34296                 0                       0                0
# 34297                 0                       0                0
# 34298                 1                       0                0
#
#        INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y  \
# 0                      0                         1                         0
# 1                      0                         1                         0
# 2                      0                         1                         0
# 3                      0                         1                         0
# 4                      0                         1                         0
# ...                  ...                       ...                       ...
# 34294                  0                         1                         0
# 34295                  0                         1                         0
# 34296                  0                         1                         0
# 34297                  0                         1                         0
# 34298                  0                         1                         0
#
#        ASK_AMT_5000  ASK_AMT_Other
# 0                 1              0
# 1                 0              1
# 2                 1              0
# 3                 0              1
# 4                 0              1
# ...             ...            ...
# 34294             1              0
# 34295             1              0
# 34296             1              0
# 34297             1              0
# 34298             0              1
#
# [34299 rows x 44 columns]

# %%
y = dummies_df.IS_SUCCESSFUL.values
X = dummies_df.drop(columns = 'IS_SUCCESSFUL').values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1, stratify = y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model
nn_2 = tf.keras.models.Sequential()

input_dims = len(X_train[0])

# First hidden layer
nn_2.add(tf.keras.layers.Dense(units = 80, activation = 'tanh', input_dim = input_dims))

# Add dropout layer
tf.keras.layers.Dropout(0.5)

# Second hidden layer
nn_2.add(tf.keras.layers.Dense(units = 30, activation = 'tanh'))

# Add dropout layer
tf.keras.layers.Dropout(0.5)

# Output layer
nn_2.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn_2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Import Early Stopping Library
from keras.callbacks import EarlyStopping

# %%
# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# %%
# Train the model
nn_2.fit(X_train_scaled, y_train, epochs=100, batch_size=10, validation_data=(X_test_scaled, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 2573/2573 [==============================] - 7s 2ms/step - loss: 0.5692 - accuracy: 0.7213 - val_loss: 0.5599 - val_accuracy: 0.7255
# Epoch 2/100
# 2573/2573 [==============================] - 7s 3ms/step - loss: 0.5550 - accuracy: 0.7282 - val_loss: 0.5570 - val_accuracy: 0.7271
# Epoch 3/100
# 2573/2573 [==============================] - 5s 2ms/step - loss: 0.5515 - accuracy: 0.7301 - val_loss: 0.5596 - val_accuracy: 0.7186
# Epoch 4/100
# 2573/2573 [==============================] - 10s 4ms/step - loss: 0.5490 - accuracy: 0.7294 - val_loss: 0.5549 - val_accuracy: 0.7272
# Epoch 5/100
# 2573/2573 [==============================] - 8s 3ms/step - loss: 0.5473 - accuracy: 0.7328 - val_loss: 0.5556 - val_accuracy: 0.7248
# Epoch 6/100
# 2573/2573 [==============================] - 5s 2ms/step - loss: 0.5459 - accuracy: 0.7331 - val_loss: 0.5544 - val_accuracy: 0.7287
# Epoch 7/100
# 2573/2573 [==============================] - 7s 3ms/step - loss: 0.5447 - accuracy: 0.7337 - val_loss: 0.5580 - val_accuracy: 0.7294
# Epoch 8/100
# 2573/2573 [==============================] - 6s 2ms/step - loss: 0.5439 - accuracy: 0.7333 - val_loss: 0.5548 - val_accuracy: 0.7283
# Epoch 9/100
# 2573/2573 [==============================] - 7s 3ms/step - loss: 0.5427 - accuracy: 0.7351 - val_loss: 0.5557 - val_accuracy: 0.7278
# Epoch 10/100
# 2573/2573 [==============================] - 6s 2ms/step - loss: 0.5423 - accuracy: 0.7343 - val_loss: 0.5544 - val_accuracy: 0.7297
# Epoch 11/100
# 2573/2573 [==============================] - 6s 2ms/step - loss: 0.5414 - accuracy: 0.7362 - val_loss: 0.5553 - val_accuracy: 0.7286
# Epoch 12/100
# 2573/2573 [==============================] - 5s 2ms/step - loss: 0.5411 - accuracy: 0.7362 - val_loss: 0.5537 - val_accuracy: 0.7287
# Epoch 13/100
# 2573/2573 [==============================] - 7s 3ms/step - loss: 0.5403 - accuracy: 0.7363 - val_loss: 0.5548 - val_accuracy: 0.7255
# Epoch 14/100
# 2573/2573 [==============================] - 6s 3ms/step - loss: 0.5394 - accuracy: 0.7357 - val_loss: 0.5539 - val_accuracy: 0.7299
# Epoch 15/100
# 2573/2573 [==============================] - 7s 3ms/step - loss: 0.5398 - accuracy: 0.7371 - val_loss: 0.5542 - val_accuracy: 0.7289
# Epoch 16/100
# 2573/2573 [==============================] - 5s 2ms/step - loss: 0.5391 - accuracy: 0.7355 - val_loss: 0.5562 - val_accuracy: 0.7300
# Epoch 17/100
# 2573/2573 [==============================] - 7s 3ms/step - loss: 0.5389 - accuracy: 0.7355 - val_loss: 0.5529 - val_accuracy: 0.7308
# Epoch 18/100
# 2573/2573 [==============================] - 5s 2ms/step - loss: 0.5384 - accuracy: 0.7367 - val_loss: 0.5569 - val_accuracy: 0.7185
# Epoch 19/100
# 2573/2573 [==============================] - 7s 3ms/step - loss: 0.5380 - accuracy: 0.7366 - val_loss: 0.5543 - val_accuracy: 0.7250
# Epoch 20/100
# 2573/2573 [==============================] - 6s 2ms/step - loss: 0.5377 - accuracy: 0.7376 - val_loss: 0.5543 - val_accuracy: 0.7319
# Epoch 21/100
# 2573/2573 [==============================] - 6s 2ms/step - loss: 0.5372 - accuracy: 0.7379 - val_loss: 0.5547 - val_accuracy: 0.7303
# Epoch 22/100
# 2573/2573 [==============================] - 5s 2ms/step - loss: 0.5375 - accuracy: 0.7372 - val_loss: 0.5538 - val_accuracy: 0.7300
# Epoch 23/100
# 2573/2573 [==============================] - 7s 3ms/step - loss: 0.5367 - accuracy: 0.7363 - val_loss: 0.5547 - val_accuracy: 0.7272
# Epoch 24/100
# 2573/2573 [==============================] - 7s 3ms/step - loss: 0.5364 - accuracy: 0.7378 - val_loss: 0.5553 - val_accuracy: 0.7293
# Epoch 25/100
# 2573/2573 [==============================] - 6s 2ms/step - loss: 0.5362 - accuracy: 0.7381 - val_loss: 0.5566 - val_accuracy: 0.7292

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5543 - accuracy: 0.7319 - 313ms/epoch - 1ms/step
# Loss: 0.5542990565299988, Accuracy: 0.7318950295448303

# %%
# Export our model to HDF5 file
nn_2.save('HDF5 files/AlphabetSoupCharity_Optimization_3.h5')
